# %%
import numpy as np
import matplotlib.pyplot as plt
import soundfile as sf  
from scipy.fft import fft,fftfreq

path =r"C:\Users\pcDK\dennryokuken\soturon\program\sound_from_harvard\thunder\AnyConv.com__1-23222-A.wav"
data, samplerate = sf.read(path)    
print(data,samplerate)
T=1/samplerate#サンプリング周期
N=len(data)#サンプル数
print(N)
Figure=plt.figure()
figure1=Figure.add_subplot(2,1,1)
figure2=Figure.add_subplot(2,1,2)
plt.subplots_adjust(hspace=1)
#FFT↓
FFT=fft(data)
print(FFT)
f=fftfreq(N,T)[:N//2]
figure1.set_xlabel("frequency(Hz)")
figure1.set_ylabel("signal amplitude")
figure1.plot(f,2.0/N*np.abs(FFT[0:N//2]))

print(f)
FFT_abs=abs(FFT)
M=max(FFT_abs)
print(M)
A=np.where(FFT_abs==M)
print(A)
print(f[66])
figure2.set_xlabel("frequency(Hz)")
figure2.set_ylabel("signal amplitude")
figure2.plot(f,2.0/N*np.abs(FFT[0:N//2]))
figure2.set_xlim(0,100)
# Out:
# [-0.07241821 -0.06552124 -0.04418945 ... -0.00015259 -0.00012207
#  -0.00012207] 44100
# 221248
# [65.73208618-0.j         66.84257727+1.22971774j 54.02228151+2.54207264j
#  ... 82.31571622-9.74954676j 54.02228151-2.54207264j
#  66.84257727-1.22971774j]
# [0.00000000e+00 1.99323836e-01 3.98647671e-01 ... 2.20494020e+04
#  2.20496014e+04 2.20498007e+04]
# 1695.2843944297895
# (array([    66, 221182], dtype=int64),)
# 13.155373155915536
# (0.0, 100.0)
